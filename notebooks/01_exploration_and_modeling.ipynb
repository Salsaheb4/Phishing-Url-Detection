# %% [markdown]
# # Phishing URL Exploration and Modeling
#
# This notebook is a lightweight companion to the main script-based workflow. The primary experiment path is `run_experiment.py`.

# %%
import pandas as pd

df = pd.read_csv('../data/web_page_phishing.csv')
df.head()

# %%
df.shape, df.columns.tolist()

# %% [markdown]
# Run the full experiment from the project root:
#
# ```bash
# python run_experiment.py --data data/web_page_phishing.csv --target phishing
# ```
